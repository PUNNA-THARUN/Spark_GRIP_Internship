# %% [markdown]
#     Task 5- Perform Exploratory Data Analysis on dataset 'Indian Premier League'
#     By - Punna Tharun Data Science & Business Analytics intern at The Sparks Foundation (TSF)

# %% [markdown]
# # Step -1:- Importing the necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step-2: Importing Dataset

# %%
deli_df = pd.read_csv("D:\\Desktop\\Spark\\deliveries.csv")

# %%
deli_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
mat_df = pd.read_csv("D:\\Desktop\\Spark\\matches.csv")

# %%
mat_df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Checking data sets insights

# %%
print("Shape of delivaries :", deli_df.shape)
print("Shape of matces :", mat_df.shape)
# Out:
# Shape of delivaries : (179078, 21)
# Shape of matces : (756, 18)

# %%
print("delivaries dataset Summary\n","-"*60, sep="")
deli_df.info()
# Out:
# delivaries dataset Summary
# ------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
# ...

# %%
print("matches dataset Summary\n","-"*60, sep="")
mat_df.info()
# Out:
# matches dataset Summary
# ------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
# ...

# %%
print("delivaries statistical Summary\n","-"*60, sep="")
deli_df.describe()
# Out:
# delivaries statistical Summary
# ------------------------------------------------------------
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# ...

# %%
print("matches statistical Summary\n","-"*60, sep="")
mat_df.describe()
# Out:
# matches statistical Summary
# ------------------------------------------------------------
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
# Finding Null values in datasets

print("delivaries null vaues\n","-"*60, sep="")
deli_df.isnull().sum()
# Out:
# delivaries null vaues
# ------------------------------------------------------------
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
print("matches null vaues\n","-"*60, sep="")
mat_df.isnull().sum()
# Out:
# matches null vaues
# ------------------------------------------------------------
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
mat_df.drop('umpire3', axis=1, inplace=True)

# %%
mat_df.fillna(0, inplace=True)

# %%
mat_df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
# deli_df.fillna(0, inplace=True)

# %%
deli_df.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %% [markdown]
# # Merging Two data sets

# %%
winner_data = mat_df[['id','season','winner']]
df = deli_df.merge(winner_data, how= "inner", left_on= "match_id", right_on= "id")

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  penalty_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...             0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...             0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...             0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...             0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...             0
#
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'winner'],
#       dtype='object')

# %%
df.shape
# Out:
# (179078, 24)

# %%
plt.figure(figsize= (12,6))
sns.countplot(x= "season", data= mat_df, palette= "Paired" )
plt.title("SEASON vs MATCHES PLAYED", fontsize= 20)
plt.xticks(rotation= 45)
plt.xlabel("SEASON", fontsize=20)
plt.ylabel("MATCHES", fontsize=20)
# Out:
# Text(0, 0.5, 'MATCHES')

# %%
plt.figure(figsize= (15,6))
sns.countplot(x= "winner", data= df, palette= "muted" )
plt.title("TEAMS vs No. OF WINS", fontsize= 20)
plt.xticks(rotation= 90)
plt.xlabel("TEAMS", fontsize=20)
plt.ylabel("No. OF WINS", fontsize=20)
# Out:
# Text(0, 0.5, 'No. OF WINS')

# %%
result = mat_df.result.value_counts()
result
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
plt.figure(figsize=(8,6))
color = sns.color_palette("bright")
plt.pie(result, labels=['Normal', "Tie", "No Result"], colors= color, autopct= '%.2f', 
        pctdistance=1.1, labeldistance=1.2)
plt.show()

# %%
plt.subplots(figsize=(18,8))
sns.countplot(x='season', hue='toss_decision', data= mat_df)
plt.show()

# %%
# Wickets taken by Bowling Team

sns.set_style('whitegrid')
plt.figure(figsize=(22, 10))
sns.countplot(x='bowling_team', hue='dismissal_kind', data= deli_df)
plt.title('DISTRIBUTION OF WICKET TAKEN BY BOWLING TEAM', fontsize=28)
plt.xlabel('BOWLING TEAM', fontsize=22)
plt.ylabel('NUMBER OF WICKET', fontsize=22)
plt.xticks(rotation=90)
plt.show()

# %%
# Matches played by all teams in all seasons

plt.subplots(figsize=(16,6))
clr = sns.color_palette('dark', 20)
ploting = mat_df['toss_winner'].value_counts().plot.bar(width=0.9,color= clr)
for mat in ploting.patches:
          ploting.annotate(format(mat.get_height()),(mat.get_x()+0.15, mat.get_height()+1))
plt.title('TOTAL MATCHES PLAYED BY TEAMS', fontsize=28)
plt.xlabel('TEAMS', fontsize=22)
plt.ylabel('TOTAL MATCHES', fontsize=22)
plt.xticks(rotation=90)
plt.show()

# %%
# Most Successful Batsmans in Entire IPL Seasons
plt.subplots(figsize=(15,6))
max_runs = df.groupby(['batsman'])['batsman_runs'].sum()
clr = sns.color_palette('pastel',20)
ax = max_runs.sort_values(ascending=False)[:10].plot.bar(width=0.8,color=clr)
for p in ax.patches:
    ax.annotate(format(p.get_height()),(p.get_x()+0.1, p.get_height()+50),fontsize=15)
plt.title('MOST SUCCESSFUL BATSMAN IN IPL', fontsize=28)
plt.xlabel('PLAYER', fontsize=22)
plt.ylabel('HIGHEST RUNS', fontsize=22)
plt.xticks(rotation=90)
plt.show()

# %%
deli_df.dismissal_kind.unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
input = ['caught', 'bowled','lbw', 'caught and bowled', 'stumped', 'hit wicket']

wickets = deli_df[deli_df['dismissal_kind'] != ('run out', 'nan', 'retired hurt', 'obstructing the field'  )].groupby('bowler').count()['dismissal_kind']

# %%
top_10 = wickets.sort_values(ascending= False).head(10)
top_10
# Out:
# bowler
# SL Malinga         188
# DJ Bravo           168
# A Mishra           165
# Harbhajan Singh    161
# PP Chawla          156
# B Kumar            141
# R Ashwin           138
# SP Narine          137
# UT Yadav           136
# R Vinay Kumar      127
# Name: dismissal_kind, dtype: int64

# %%
#  Mostt Successful Bowlers
plt.figure(figsize=(15,8))
sns.barplot(x= top_10.index, y= top_10.values, palette="Paired")
plt.xticks(rotation=90)
plt.xlabel('PLAYERS',fontsize= 15)
plt.ylabel('WICKETS', fontsize= 15)
plt.title('MOST SUCCESSFUL BOWLERS IN IPL', fontsize= 20)
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x='season', hue='toss_winner', data=mat_df, palette='bright')
plt.title("Toss vs Wins", fontsize=20)
plt.xlabel("season", fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.show()

# %%
mat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             756 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           756 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  756 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          756 non-null    object
#  16  umpire2          756 non-null    object
# ...

# %%
winner = (mat_df[["season", "winner"]].drop_duplicates(subset= "season", keep= "last")).reset_index(drop=True).sort_values(by= "season")
winner
# Out:
#     season                 winner
# 1     2008       Rajasthan Royals
# 2     2009        Deccan Chargers
# 3     2010    Chennai Super Kings
# 4     2011    Chennai Super Kings
# 5     2012  Kolkata Knight Riders
# 6     2013         Mumbai Indians
# 7     2014  Kolkata Knight Riders
# 8     2015         Mumbai Indians
# 9     2016    Sunrisers Hyderabad
# 0     2017         Mumbai Indians
# 10    2018    Chennai Super Kings
# 11    2019         Mumbai Indians

# %%
win_matches = mat_df.winner.value_counts()

# %% [markdown]
# # Highest Wins By Teams

# %%
plt.figure(figsize=(15,8))
sns.barplot(x= win_matches.index, y= win_matches.values, palette="Paired") 
plt.title("WINING MATCHES BY EVERY TEAM", fontsize= 20)
plt.xlabel("TEAM", fontsize= 15)
plt.ylabel("MATCHES", fontsize= 15)
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# # Highest IPL cups Won by Team

# %%
winner["winner"].value_counts()
# Out:
# Mumbai Indians           4
# Chennai Super Kings      3
# Kolkata Knight Riders    2
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# Name: winner, dtype: int64

# %%
result = mat_df.drop_duplicates(subset=['season'], keep='last')
result.head()
# Out:
#       id  season          city        date                team1  \
# 58    59    2017     Hyderabad  2017-05-21       Mumbai Indians
# 116  117    2008        Mumbai  2008-06-01  Chennai Super Kings
# 173  174    2009  Johannesburg  2009-05-24      Deccan Chargers
# 233  234    2010        Mumbai  2010-04-25  Chennai Super Kings
# 306  307    2011       Chennai  2011-05-28  Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 58        Rising Pune Supergiant               Mumbai Indians           bat
# 116             Rajasthan Royals             Rajasthan Royals         field
# 173  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 233               Mumbai Indians          Chennai Super Kings           bat
# 306  Royal Challengers Bangalore          Chennai Super Kings           bat
#
#      result  dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %% [markdown]
# # Man of the match for Wining Team

# %%
result[["winner", "player_of_match"]].reset_index(drop= True)
# Out:
#                    winner player_of_match
# 0          Mumbai Indians       KH Pandya
# 1        Rajasthan Royals       YK Pathan
# 2         Deccan Chargers        A Kumble
# 3     Chennai Super Kings        SK Raina
# 4     Chennai Super Kings         M Vijay
# 5   Kolkata Knight Riders        MS Bisla
# 6          Mumbai Indians      KA Pollard
# 7   Kolkata Knight Riders       MK Pandey
# 8          Mumbai Indians       RG Sharma
# 9     Sunrisers Hyderabad     BCJ Cutting
# 10    Chennai Super Kings       SR Watson
# 11         Mumbai Indians       JJ Bumrah

# %%
deli_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# # Each team Boundaries(Fours) and Total Runs scored by Fours

# %%
fours = df[df['batsman_runs']==4]
fours.groupby('batting_team')['batsman_runs'].agg([('runs by fours','sum'),('fours','count')])
# Out:
#                              runs by fours  fours
# batting_team
# Chennai Super Kings                   8772   2193
# Deccan Chargers                       3828    957
# Delhi Capitals                         968    242
# Delhi Daredevils                      8632   2158
# Gujarat Lions                         1840    460
# Kings XI Punjab                       9832   2458
# Kochi Tuskers Kerala                   680    170
# Kolkata Knight Riders                 9736   2434
# Mumbai Indians                       10352   2588
# Pune Warriors                         2100    525
# Rajasthan Royals                      8140   2035
# Rising Pune Supergiant                 788    197
# Rising Pune Supergiants                684    171
# Royal Challengers Bangalore           9440   2360
# Sunrisers Hyderabad                   5776   1444

# %%
fours_batsman = fours.groupby('batsman')['batsman_runs'].agg([('runs_by_fours','sum'),('fours','count')])
top_batsman_fours = fours_batsman.sort_values("fours",ascending=0).iloc[:10,:]
top_batsman_fours
# Out:
#             runs_by_fours  fours
# batsman
# S Dhawan             2104    526
# SK Raina             1980    495
# G Gambhir            1968    492
# V Kohli              1928    482
# DA Warner            1836    459
# RV Uthappa           1744    436
# RG Sharma            1724    431
# AM Rahane            1620    405
# CH Gayle             1504    376
# PA Patel             1464    366

# %%
# Plotting the Top 10 of boundaries scored
plt.figure(figsize=(15,8))
sns.barplot(x= top_batsman_fours.index, y= top_batsman_fours.fours, palette="Paired")
plt.xticks(rotation=90)
plt.xlabel('PLAYERS',fontsize= 15)
plt.ylabel('No. OF FOURS', fontsize= 15)
plt.title('TOP 10 PLAYERS SCORED HIGHEST FOURS', fontsize= 20)
plt.show()

# %% [markdown]
# # Each team Sixes and Total Runs scored by Sixes

# %%
six = df[df['batsman_runs'] == 6]
six.groupby('batting_team')['batsman_runs'].agg([('runs_by_six','sum'),('sixs','count')])
# Out:
#                              runs_by_six  sixs
# batting_team
# Chennai Super Kings                 5838   973
# Deccan Chargers                     2400   400
# Delhi Capitals                       522    87
# Delhi Daredevils                    4806   801
# Gujarat Lions                        930   155
# Kings XI Punjab                     5856   976
# Kochi Tuskers Kerala                 318    53
# Kolkata Knight Riders               5580   930
# Mumbai Indians                      6576  1096
# Pune Warriors                       1176   196
# Rajasthan Royals                    4086   681
# Rising Pune Supergiant               534    89
# Rising Pune Supergiants              408    68
# Royal Challengers Bangalore         6792  1132
# Sunrisers Hyderabad                 3198   533

# %%
six_batsman = six.groupby('batsman')['batsman_runs'].agg([('runs_by_six','sum'),('sixs','count')])
top_batsman_sixs = six_batsman.sort_values("sixs",ascending=0).iloc[:10,:]
top_batsman_sixs
# Out:
#                 runs_by_six  sixs
# batsman
# CH Gayle               1962   327
# AB de Villiers         1284   214
# MS Dhoni               1242   207
# SK Raina               1170   195
# RG Sharma              1164   194
# V Kohli                1146   191
# DA Warner              1086   181
# SR Watson              1062   177
# KA Pollard             1050   175
# YK Pathan               966   161

# %%
# Plotting the Top 10 Players of Sixs scored
plt.figure(figsize=(15,8))
sns.barplot(x= top_batsman_sixs.index, y= top_batsman_sixs.sixs, palette="Paired")
plt.xticks(rotation=90)
plt.xlabel('PLAYERS',fontsize= 15)
plt.ylabel('No. OF SIXES', fontsize= 15)
plt.title('TOP 10 PLAYERS SCORED HIGHEST SIXES', fontsize= 20)
plt.show()

# %%
h_s = df.groupby('batsman')['batsman_runs'].agg(['sum'])
high_scorer = h_s.sort_values('sum', ascending= False).iloc[:10,:]
high_scorer
# Out:
#                  sum
# batsman
# V Kohli         5434
# SK Raina        5415
# RG Sharma       4914
# DA Warner       4741
# S Dhawan        4632
# CH Gayle        4560
# MS Dhoni        4477
# RV Uthappa      4446
# AB de Villiers  4428
# G Gambhir       4223

# %%
# Plotting the Top 10 Highest Scorers of IPL
plt.figure(figsize=(15,8))
sns.barplot(x= high_scorer.index, y= high_scorer['sum'].values, palette="Paired")
plt.xticks(rotation=90)
plt.xlabel('PLAYERS',fontsize= 15)
plt.ylabel('HIGHEST RUNS', fontsize= 15)
plt.title('TOP 10 PLAYERS WITH HIGHEST RUNS IN IPL', fontsize= 20)
plt.show()

# %%
bowl = df.groupby('bowler')['dismissal_kind'].agg(['count'])
high_wickets = bowl.sort_values('count', ascending= False).iloc[:10,:]
high_wickets
# Out:
#                  count
# bowler
# SL Malinga         188
# DJ Bravo           168
# A Mishra           165
# Harbhajan Singh    161
# PP Chawla          156
# B Kumar            141
# R Ashwin           138
# SP Narine          137
# UT Yadav           136
# R Vinay Kumar      127

# %%
# Plotting the Top 10 Wicket Takers of IPL
plt.figure(figsize=(15,8))
sns.barplot(x= high_wickets.index, y= high_wickets['count'].values, palette="Paired")
plt.xticks(rotation = 45)
plt.xlabel('PLAYERS',fontsize= 15)
plt.ylabel('HIGHEST WICKETS', fontsize= 15)
plt.title('TOP 10 PLAYERS WITH HIGHEST WICKETS IN IPL', fontsize= 20)
plt.show()

# %% [markdown]
# # Exploratory Data Analysis Report
#
# 1. Most Successful Team is Mumbai Indians and holds 4 IPL Cups.
# 2. Highest Matches played in 2013,2012,2011 IPL seasons.
# 3. Highest Matches winner is Mumbai Indians and Lowest is Rising pune supergiants
# 4. 98% of IPL matches are got Normal result and 1.2% matches are Tied others are no result.
# 5. Highest Matches Played by Teams is Mumbai Indians with 98 Matches and lowest is Rising pune supergiants with 6 matches.
# 6. Most Successful batsman in IPL is "Virat Kohli" and also Highest runs scorer in IPL.
# 7. Highest Wicket Taker in IPL is Malinga ans also Most Successful bowler in IPL.
# 8. Highest Sixes hitter is Gayle and Highest Boundaries hitter is S. Dawan.
# 9. More catches and bowled taken by Mumbai indians players.
# 10. Max toss decissions taken in IPL was fielding
